# %%
import xarray as xr
import glob

files = sorted(glob.glob("/Volumes/ct_data/carbon_tracker_ocean/*.nc"))
datasets = [xr.open_dataset(f) for f in files]
ds = xr.combine_by_coords(datasets)
# Out:
# /var/folders/5c/rc9sblr11n575rm6khzlpqkw0000gp/T/ipykernel_12398/1559611314.py:6: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   ds = xr.combine_by_coords(datasets)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/xarray/structure/merge.py:645, in merge_attrs(variable_attrs, combine_attrs, context)
#     644 try:
# --> 645     result = compat_dict_union(result, attrs)
#     646 except ValueError as e:
#
# ...

# %%
# !pip install dask
